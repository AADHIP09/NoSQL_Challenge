# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene' : 20}

# Use count_documents to display the number of documents in the result
hygiene_score = establishments.count_documents(query)
print(f'There are {hygiene_score} restaurants with a hygiene score of 20.')

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# There are 41 restaurants with a hygiene score of 20.
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f90d04d626b9f343d058d3'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
results = establishments.find(query)

hygiene_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
row_count = hygiene_df['_id'].count()
print(f'There are {row_count} rows in the dataframe.')

# Display the first 10 rows of the DataFrame
hygiene_df.head(6)
# Out:
# There are 41 rows in the dataframe.
#                         _id  FHRSID  ChangesByServerID  \
# 0  64f90d04d626b9f343d058d3  110681                  0
# 1  64f90d04d626b9f343d05c52  612039                  0
# 2  64f90d04d626b9f343d05f5b  730933                  0
# 3  64f90d04d626b9f343d0614d  172735                  0
# 4  64f90d04d626b9f343d0616d  172953                  0
# 5  64f90d04d626b9f343d06af8  512854                  0
#
#   LocalAuthorityBusinessID         BusinessName  \
# 0                     4029  The Chase Rest Home
# 1                1970/FOOD           Brenalwood
# 2                1698/FOOD        Melrose Hotel
# 3             PI/000023858        Seaford Pizza
# 4             PI/000024532        Golden Palace
# 5            12/00816/BUTH     Ashby's Butchers
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
#
#             LocalAuthorityEmailAddress  \
# 0      Customerfirst@eastbourne.gov.uk
# 1           fhsadmin@tendringdc.gov.uk
# 2           fhsadmin@tendringdc.gov.uk
# 3  ehealth.ldc@lewes-eastbourne.gov.uk
# 4  ehealth.ldc@lewes-eastbourne.gov.uk
# 5  EnvironmentalHealth@southend.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                           geocode RightToReply     Distance  \
# 0   {'longitude': 0.27694, 'latitude': 50.769705}               4613.888288
# 1  {'longitude': 1.278721, 'latitude': 51.857536}               4617.965824
# 2   {'longitude': 1.15927, 'latitude': 51.789429}               4619.656144
# 3   {'longitude': 0.10202, 'latitude': 50.770885}               4620.421725
# 4  {'longitude': 0.101446, 'latitude': 50.770724}               4620.437179
# 5  {'longitude': 0.736349, 'latitude': 51.541448}               4625.565258
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [6 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query_2 = {'AddressLine2': {'$regex': 'London'}, 
          'RatingValue': {'$gte': 4}
         }

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query_2)
print(f"There are {count} establishments in London that have a RatingValue greater than or equal to 4.")

# Display the first document in the results using pprint
pprint(establishments.find_one(query_2))
# Out:
# There are 404 establishments in London that have a RatingValue greater than or equal to 4.
# {'AddressLine1': 'Christchurch School',
#  'AddressLine2': 'London Road',
#  'AddressLine3': 'Ramsgate',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'ChristChurch School Breakfast Club',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4593.73405256468,
#  'FHRSID': 430092,
#  'LocalAuthorityBusinessID': 'PI/000041757',
#  'LocalAuthorityCode': '190',
#  'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#  'LocalAuthorityName': 'Thanet',
#  'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT11 0DN',
#  'RatingDate': '2022-05-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f90d03d626b9f343d04140'),
#  'geocode': {'latitude': Decimal128('51.331076'),
#              'longitude': Decimal128('1.398281')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/430092',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert the result to a Pandas DataFrame
df_2 = pd.DataFrame(establishments.find(query_2))

# Display the number of rows in the DataFrame
print(f"There are {len(df_2)} rows in this DataFrame.")

# Display the first 10 rows of the DataFrame
df_2.head(10)
# Out:
# There are 404 rows in this DataFrame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f90d03d626b9f343d04140   430092                  0
# 1  64f90d03d626b9f343d04a71  1102585                  0
# 2  64f90d03d626b9f343d04a87  1102587                  0
# 3  64f90d03d626b9f343d04c78  1088382                  0
# 4  64f90d03d626b9f343d04c8e   171862                  0
# 5  64f90d03d626b9f343d04ce5  1425349                  0
# 6  64f90d03d626b9f343d04f85  1154078                  0
# 7  64f90d03d626b9f343d04fce  1264573                  0
# 8  64f90d03d626b9f343d04fd1  1154080                  0
# 9  64f90d03d626b9f343d05005   956339                  0
#
#   LocalAuthorityBusinessID                             BusinessName  \
# 0             PI/000041757       ChristChurch School Breakfast Club
# 1                    57305                             Acacia Lodge
# 2                    57323  Pilgrims Hospice & Ann Robertson Centre
# 3             PI/000076330                                 Best One
# 4             PI/000021565                     Laurels Nursing Home
# 5             PI/000078378                          Premier Express
# 6             PI/000076979                      Breakfast Zone Cafe
# 7             PI/000077558                          Milk and Hustle
# 8             PI/000076981                                 Catch 22
# 9             PI/000075326                   FSN - St Nicks Nursery
#
#                         BusinessType  BusinessTypeID  \
# 0          School/college/university            7845
# 1  Hotel/bed & breakfast/guest house            7842
# 2                    Caring Premises               5
# 3                  Retailers - other            4613
# 4                    Caring Premises               5
# 5                  Retailers - other            4613
# 6            Restaurant/Cafe/Canteen               1
# 7                  Retailers - other            4613
# 8             Takeaway/sandwich shop            7844
# 9                    Caring Premises               5
#
#                AddressLine1          AddressLine2        AddressLine3  ...  \
# 0       Christchurch School           London Road            Ramsgate  ...
# 1                Tanglewood        40 London Road          Canterbury  ...
# 2          Pilgrims Hospice  55 - 56A London Road          Canterbury  ...
# 3                      Shop   480 Old London Road            Hastings  ...
# 4  The Laurels Nursing Home    71 Old London Road            Hastings  ...
# 5         Shop and Premises   384 Old London Road            Hastings  ...
# 6         Cafe and Premises       13B London Road  St Leonards-on-sea  ...
# 7         Shop and premises       45B London Road  St Leonards-on-sea  ...
# 8         Shop and Premises   470 Old London Road            Hastings  ...
# 9        St Nicholas Centre        66 London Road  St Leonards-on-sea  ...
#
#           LocalAuthorityWebSite          LocalAuthorityEmailAddress  \
# 0      http://www.thanet.gov.uk  environmental.health@thanet.gov.uk
# 1  http://www.canterbury.gov.uk
# 2  http://www.canterbury.gov.uk
# 3    http://www.hastings.gov.uk                fhrs@hastings.gov.uk
# 4    http://www.hastings.gov.uk                fhrs@hastings.gov.uk
# 5    http://www.hastings.gov.uk                fhrs@hastings.gov.uk
# 6    http://www.hastings.gov.uk                fhrs@hastings.gov.uk
# 7    http://www.hastings.gov.uk                fhrs@hastings.gov.uk
# 8    http://www.hastings.gov.uk                fhrs@hastings.gov.uk
# 9    http://www.hastings.gov.uk                fhrs@hastings.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 6  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 1.398281, 'latitude': 51.331076}
# 1   {'longitude': 1.0676288, 'latitude': 51.2831611}
# 2   {'longitude': 1.0647485, 'latitude': 51.2823371}
# 3  {'longitude': 0.608790993690491, 'latitude': 5...
# 4   {'longitude': 0.5985562, 'latitude': 50.8630193}
# 5  {'longitude': 0.608383600007958, 'latitude': 5...
# 6   {'longitude': 0.5604566, 'latitude': 50.8524211}
# 7  {'longitude': 0.55984902381897, 'latitude': 50...
# 8   {'longitude': 0.5599696, 'latitude': 50.8539068}
# 9     {'longitude': 0.558641, 'latitude': 50.855821}
#
#       Distance NewRatingPending  \
# 0  4593.734053            False
# 1  4603.901535            False
# 2  4603.975171            False
# 3  4605.406701            False
# 4  4605.426987            False
# 5  4605.488305            False
# 6  4606.441026            False
# 7  4606.522503            False
# 8  4606.513771            False
# 9  4606.633360            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.083812
longitude = 1.195625

query_3 = {'RatingValue': 5, 
         'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)}, 
         'geocode.longitude': {'$lte': (longitude + degree_search), '$gte': (longitude - degree_search)} 
         }
sort =  [('scores.Hygiene', 1)]
limit = 5
 

# Print the results
for result in establishments.find(query_3).sort(sort).limit(limit):
    pprint(result)
# Out:
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Little Rock',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1423242,
#  'LocalAuthorityBusinessID': 'PI/000078141',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f90d03d626b9f343d03db0'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1423242',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '42 North Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Lifeboat',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4592.005041613854,
#  'FHRSID': 511409,
#  'LocalAuthorityBusinessID': 'PI/000039931',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AF',
#  'RatingDate': '2020-07-22T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f90d03d626b9f343d03de1'),
#  'geocode': {'latitude': Decimal128('51.081546'),
#              'longitude': Decimal128('1.186715')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/511409',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '16 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Mariner',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 289560,
#  'LocalAuthorityBusinessID': 'PI/000039927',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2019-03-19T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f90d03d626b9f343d03dab'),
#  'geocode': {'latitude': Decimal128('51.08084'),
#              'longitude': Decimal128('1.188537')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289560',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4591.871474174837,
#  'FHRSID': 289353,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6QH',
#  'RatingDate': '2016-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f90d03d626b9f343d03da4'),
#  'geocode': {'latitude': Decimal128('51.085797'),
#              'longitude': Decimal128('1.194762')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Custom Folkestone',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1046418,
#  'LocalAuthorityBusinessID': 'PI/000076426',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-11-30T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f90d03d626b9f343d03daf'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1046418',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# Convert result to Pandas DataFrame
results = list(establishments.find(query_3).sort(sort).limit(limit))

top_5_df = pd.DataFrame(results)

top_5_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f90d03d626b9f343d03db0  1423242                  0
# 1  64f90d03d626b9f343d03de1   511409                  0
# 2  64f90d03d626b9f343d03dab   289560                  0
# 3  64f90d03d626b9f343d03da4   289353                  0
# 4  64f90d03d626b9f343d03daf  1046418                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000078141                          Little Rock
# 1             PI/000039931                         The Lifeboat
# 2             PI/000039927                              Mariner
# 3             PI/000002468  St Marys COE (aided) Primary School
# 4             PI/000076426                    Custom Folkestone
#
#                 BusinessType  BusinessTypeID  \
# 0    Other catering premises            7841
# 1          Pub/bar/nightclub            7843
# 2          Pub/bar/nightclub            7843
# 3  School/college/university            7845
# 4    Restaurant/Cafe/Canteen               1
#
#                                 AddressLine1           AddressLine2  \
# 0                         Folkestone Harbour  Harbour Approach Road
# 1                            42 North Street             Folkestone
# 2                               16 The Stade             Folkestone
# 3  St Marys Church Of England Primary School            Warren Road
# 4                         Folkestone Harbour  Harbour Approach Road
#
#   AddressLine3  ...               LocalAuthorityWebSite  \
# 0   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 1         Kent  ...  http://www.folkestone-hythe.gov.uk
# 2         Kent  ...  http://www.folkestone-hythe.gov.uk
# 3   Folkestone  ...  http://www.folkestone-hythe.gov.uk
# 4   Folkestone  ...  http://www.folkestone-hythe.gov.uk
#
#          LocalAuthorityEmailAddress  \
# 0  foodteam@folkestone-hythe.gov.uk
# 1  foodteam@folkestone-hythe.gov.uk
# 2  foodteam@folkestone-hythe.gov.uk
# 3  foodteam@folkestone-hythe.gov.uk
# 4  foodteam@folkestone-hythe.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
# 1  {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 1.18590330311705, 'latitude': 51...
# 1     {'longitude': 1.186715, 'latitude': 51.081546}
# 2      {'longitude': 1.188537, 'latitude': 51.08084}
# 3     {'longitude': 1.194762, 'latitude': 51.085797}
# 4  {'longitude': 1.18590330311705, 'latitude': 51...
#
#       Distance NewRatingPending  \
# 0  4591.914705            False
# 1  4592.005042            False
# 2  4591.912145            False
# 3  4591.871474            False
# 4  4591.914705            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match' : {'scores.Hygiene' : 0}}
# 2. Groups the matches by Local Authority
group_query = {'$group' :{ '_id' : '$LocalAuthorityName' , 'count' : {'$sum' : 1}}}
# 3. Sorts the matches from highest to lowest
sort_query = {'$sort' : {'count' : -1}}

pipeline = [match_query , group_query , sort_query]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f'The number of establishments with a hygiene score of 0 is: {len(results)}.')

# Print the first 10 results
pprint(results[0:10])
# Out:
# The number of establishments with a hygiene score of 0 is: 55.
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygiene_score_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
number_of_rows = hygiene_score_df['_id'].count()
print(f'There are {number_of_rows} rows in the dataframe.')

# Display the first 10 rows of the DataFrame
hygiene_score_df.head(10)
# Out:
# There are 55 rows in the dataframe.
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
